# %% [markdown]
# ##               Welcome to the Baruch AIS Data Analysis Workshop

# %% [markdown]
# ### Part 1.1  Data Exploration and Cleaning of Transactions Worksheet

# %% [markdown]
# #### 1. Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import datetime

# %% [markdown]
# #### 2. Import and Explore datasets

# %%
df1= pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 'Transactions', index_col = [0], 
                           parse_dates= ['transaction_date'])

df2= pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 'CustomerDemographic', index_col = [0])

# %%
df1.head(3)
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
#
#                order_status          brand product_line product_class  \
# transaction_id
# 1                  Approved          Solex     Standard        medium
# 2                  Approved  Trek Bicycles     Standard        medium
# 3                  Approved     OHM Cycles     Standard           low
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
#
#                 product_first_sold_date
# transaction_id
# 1                               41245.0
# 2                               41701.0
# 3                               36361.0

# %%
df1.describe()
# Out:
#         product_id   customer_id  online_order    list_price  standard_cost  \
# count  20000.00000  20000.000000  19640.000000  20000.000000   19803.000000
# mean      45.36465   1738.246050      0.500458   1107.829449     556.046951
# std       30.75359   1011.951046      0.500013    582.825242     405.955660
# min        0.00000      1.000000      0.000000     12.010000       7.210000
# 25%       18.00000    857.750000      0.000000    575.270000     215.140000
# 50%       44.00000   1736.000000      1.000000   1163.890000     507.580000
# 75%       72.00000   2613.000000      1.000000   1635.300000     795.100000
# max      100.00000   5034.000000      1.000000   2091.470000    1759.850000
#
#        product_first_sold_date
# count             19803.000000
# mean              38199.776549
# std                2875.201110
# min               33259.000000
# 25%               35667.000000
# 50%               38216.000000
# 75%               40672.000000
# max               42710.000000

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
print(df1.dropna().shape)
print(df1.shape)
# Out:
# (19445, 12)
# (20000, 12)

# %%
df_trans= df1.dropna()

# %%
df_trans.head()
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 5                       78          787       2017-10-01           1.0
#
#                order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
# 4                    medium     1198.46         381.10
# 5                     large     1765.30         709.48
#
#                 product_first_sold_date
# transaction_id
# 1                               41245.0
# 2                               41701.0
# 3                               36361.0
# 4                               36145.0
# 5                               42226.0

# %% [markdown]
# ### Part I.II: Analysis of Transaction Worksheet
#
# #### 1. What is the most popular brand?

# %%
Brand= df_trans.brand.value_counts()
type(Brand)
print(Brand)
# Out:
# Solex             4169
# WeareA2B          3245
# Giant Bicycles    3244
# OHM Cycles        2993
# Trek Bicycles     2931
# Norco Bicycles    2863
# Name: brand, dtype: int64

# %% [markdown]
# #### Pie Chart to demonstrate - Rule of Thumb - no more than 5 categories, we make an exception!

# %%
## Convert Pandas Series to 1D- array
x= Brand.values
type(x)
print(x)
# Out:
# [4169 3245 3244 2993 2931 2863]

# %%
# Define labels

x= Brand.values

fig, ax = plt.subplots(figsize=(7, 4))

Labels = ['Solex', 'WeareA2B', 'Giant Bicycles', 'OHM Cycles', 'Trek Bicycles', 'Norco Bicycles']

#Define colors
colors = np.array(['lightpink', 'crimson', 'hotpink', 'orchid', ''])
colors1= np.array(['steelblue','lightskyblue','skyblue', 'lightblue', 'dodgerblue', 'deepskyblue'])

#number labels
explode = (0.15, 0, 0, 0, 0, 0)

plt.pie(x, explode= explode, labels= Labels, colors= colors1, radius= 2,
       shadow = True, autopct='%1.1f%%')

#ax.set_title("Product Lines")


#wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  #textprops=dict(color="w"))

ax.legend(Labels, title="Brands", loc="center right",bbox_to_anchor=(1.5, 0, 1, 1))

plt.show()

# %% [markdown]
# #### 2. Which brand was most profitable?

# %%
df_trans['profit']= df_trans['list_price']- df_trans['standard_cost']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_trans.head()
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 5                       78          787       2017-10-01           1.0
#
#                order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
# 4                    medium     1198.46         381.10
# 5                     large     1765.30         709.48
#
#                 product_first_sold_date   profit
# transaction_id
# 1                               41245.0    17.87
# 2                               41701.0  1702.55
# 3                               36361.0  1544.61
# 4                               36145.0   817.36
# 5                               42226.0  1055.82

# %%
df_trans['profit']= df_trans['profit'].round(0)
df_trans.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 5                       78          787       2017-10-01           1.0
#
#                order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
# 4                    medium     1198.46         381.10
# 5                     large     1765.30         709.48
#
#                 product_first_sold_date  profit
# transaction_id
# 1                               41245.0    18.0
# 2                               41701.0  1703.0
# 3                               36361.0  1545.0
# 4                               36145.0   817.0
# 5                               42226.0  1056.0

# %%
#Brand_Profit= df_trans[['brand', 'profit']]
Brand_Profit.head()
# Out:
#                          brand  profit
# transaction_id
# 1                        Solex    18.0
# 2                Trek Bicycles  1703.0
# 3                   OHM Cycles  1545.0
# 4               Norco Bicycles   817.0
# 5               Giant Bicycles  1056.0

# %%
z = Brand_Profit.groupby("brand").sum()
z
z.values
# Out:
# array([[1541412.],
#        [ 853446.],
#        [1453484.],
#        [2355335.],
#        [1807209.],
#        [2717364.]])

# %%
x= ['Giant', 'Norco', 'OHM', 'Solex', 'Trek', 'WeareA2B']
y= [1541412., 853446.,1453484., 2355335., 1807209.,2717364.]

plt.title("Profits by Brand")

colors = np.array(['lightpink', 'lightpink', 'lightpink', 'lightpink', 'lightpink', 'deeppink'])

#plt.xlabel(labels, fontweight='bold', color = 'orange', fontsize='9', horizontalalignment='center')

plt.bar(x, y, color= colors)
plt.show()

# %% [markdown]
# #### 3. Which month was most profitable?

# %%
df_trans.head()
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 5                       78          787       2017-10-01           1.0
#
#                order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
# 4                    medium     1198.46         381.10
# 5                     large     1765.30         709.48
#
#                 product_first_sold_date  profit
# transaction_id
# 1                               41245.0    18.0
# 2                               41701.0  1703.0
# 3                               36361.0  1545.0
# 4                               36145.0   817.0
# 5                               42226.0  1056.0

# %%
df_trans["Month"]= df_trans["transaction_date"].apply(lambda x: x.month)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_trans.head()
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 5                       78          787       2017-10-01           1.0
#
#                order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
#                product_size  list_price  standard_cost  \
# transaction_id
# 1                    medium       71.49          53.62
# 2                     large     2091.47         388.92
# 3                    medium     1793.43         248.82
# 4                    medium     1198.46         381.10
# 5                     large     1765.30         709.48
#
#                 product_first_sold_date  profit  Month
# transaction_id
# 1                               41245.0    18.0      2
# 2                               41701.0  1703.0      5
# 3                               36361.0  1545.0     10
# 4                               36145.0   817.0      8
# 5                               42226.0  1056.0     10

# %%
s = df_trans[['profit', 'Month']]
s.head()
# Out:
#                 profit  Month
# transaction_id
# 1                 18.0      2
# 2               1703.0      5
# 3               1545.0     10
# 4                817.0      8
# 5               1056.0     10

# %%
t= df_trans[['list_price', "Month"]]
t.head()
# Out:
#                 list_price  Month
# transaction_id
# 1                    71.49      2
# 2                  2091.47      5
# 3                  1793.43     10
# 4                  1198.46      8
# 5                  1765.30     10

# %%
List_Price_Month=t.groupby("Month").sum()
List_Price_Month
# Out:
#        list_price
# Month
# 1      1814943.49
# 2      1744536.31
# 3      1752618.98
# 4      1791861.52
# 5      1864538.66
# 6      1709785.22
# 7      1837843.44
# 8      1882049.62
# 9      1698320.44
# 10     1911531.54
# 11     1755629.99
# 12     1768512.51

# %%
x1= Sales_by_Month.index
y1 = Sales_by_Month["profit"]
y2= List_Price_Month["list_price"]

fig, ax = plt.subplots()
ax.plot(x1, y1)

line= ax.plot(x1, y1, color= 'skyblue')
line= ax.plot(x1, y2, color= 'hotpink')

ax.set(xlabel='Months', ylabel='Profits',
       title='Profits per Month')

plt.show()

# %%
Sales_by_Month.profit.max()
# Out:
# 968927.0

# %% [markdown]
# ### Part 2.1: Clean and Explore Customer Worksheet

# %%
df2.head()
# Out:
#                  first_name  last_name  gender  \
# customer_id
# 1                   Laraine  Medendorp       F
# 2                       Eli    Bockman    Male
# 3                     Arlin     Dearle    Male
# 4                    Talbot        NaN    Male
# 5            Sheila-kathryn     Calton  Female
#
#              past_3_years_bike_related_purchases        DOB  \
# customer_id
# 1                                             93 1953-10-12
# 2                                             81 1980-12-16
# 3                                             61 1954-01-20
# 4                                             33 1961-10-03
# 5                                             56 1977-05-13
#
#                           job_title job_industry_category     wealth_segment  \
# customer_id
# 1               Executive Secretary                Health      Mass Customer
# 2            Administrative Officer    Financial Services      Mass Customer
# 3                Recruiting Manager              Property      Mass Customer
# 4                               NaN                    IT      Mass Customer
# 5                     Senior Editor                   NaN  Affluent Customer
#
#             deceased_indicator  \
# customer_id
# 1                            N
# 2                            N
# 3                            N
# 4                            N
# 5                            N
#
#                                                        default owns_car  \
# customer_id
# 1                                                           "'      Yes
# 2                                 <script>alert('hi')</script>      Yes
# 3                                          2018-02-01 00:00:00      Yes
# 4            () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No
# 5                                                          NIL      Yes
#
#              tenure
# customer_id
# 1              11.0
# 2              16.0
# 3              15.0
# 4               7.0
# 5               8.0

# %%
df_Cust= df2.drop(columns = ["first_name", "last_name", "deceased_indicator", "default"])
df_Cust.head()
# Out:
#              gender  past_3_years_bike_related_purchases        DOB  \
# customer_id
# 1                 F                                   93 1953-10-12
# 2              Male                                   81 1980-12-16
# 3              Male                                   61 1954-01-20
# 4              Male                                   33 1961-10-03
# 5            Female                                   56 1977-05-13
#
#                           job_title job_industry_category     wealth_segment  \
# customer_id
# 1               Executive Secretary                Health      Mass Customer
# 2            Administrative Officer    Financial Services      Mass Customer
# 3                Recruiting Manager              Property      Mass Customer
# 4                               NaN                    IT      Mass Customer
# 5                     Senior Editor                   NaN  Affluent Customer
#
#             owns_car  tenure
# customer_id
# 1                Yes    11.0
# 2                Yes    16.0
# 3                Yes    15.0
# 4                 No     7.0
# 5                Yes     8.0

# %%
df_Cust.shape
# Out:
# (4000, 8)

# %%
df_Cust.gender.value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# M            1
# Femal        1
# F            1
# Name: gender, dtype: int64

# %% [markdown]
# #### Standardize the gender column

# %%
df_Cust.gender.replace({"U": "Undefined", "Femal": "Female", "M": "Male", "F": "Female"}, inplace= True)

# %%
df_Cust.head()
# Out:
#              gender  past_3_years_bike_related_purchases        DOB  \
# customer_id
# 1            Female                                   93 1953-10-12
# 2              Male                                   81 1980-12-16
# 3              Male                                   61 1954-01-20
# 4              Male                                   33 1961-10-03
# 5            Female                                   56 1977-05-13
#
#                           job_title job_industry_category     wealth_segment  \
# customer_id
# 1               Executive Secretary                Health      Mass Customer
# 2            Administrative Officer    Financial Services      Mass Customer
# 3                Recruiting Manager              Property      Mass Customer
# 4                               NaN                    IT      Mass Customer
# 5                     Senior Editor                   NaN  Affluent Customer
#
#             owns_car  tenure
# customer_id
# 1                Yes    11.0
# 2                Yes    16.0
# 3                Yes    15.0
# 4                 No     7.0
# 5                Yes     8.0

# %% [markdown]
# ### Part 2.2 : Analysis of Customer Worksheet

# %% [markdown]
# #### 1. 	Which age group spent most money on products based on 2017 Transactions?

# %% [markdown]
# #### Change the DOB to age

# %%
def get_age(df):
    now = datetime.datetime.now()
    df['age']= now.year - pd.DatetimeIndex(df['DOB']).year
    df.drop(columns=["DOB"], inplace=True)
    return df['age']

# %%
get_age(df_Cust)
df_Cust.head()
# Out:
#              gender  past_3_years_bike_related_purchases  \
# customer_id
# 1            Female                                   93
# 2              Male                                   81
# 3              Male                                   61
# 4              Male                                   33
# 5            Female                                   56
#
#                           job_title job_industry_category     wealth_segment  \
# customer_id
# 1               Executive Secretary                Health      Mass Customer
# 2            Administrative Officer    Financial Services      Mass Customer
# 3                Recruiting Manager              Property      Mass Customer
# 4                               NaN                    IT      Mass Customer
# 5                     Senior Editor                   NaN  Affluent Customer
#
#             owns_car  tenure   age
# customer_id
# 1                Yes    11.0  67.0
# 2                Yes    16.0  40.0
# 3                Yes    15.0  66.0
# 4                 No     7.0  59.0
# 5                Yes     8.0  43.0

# %%
def age_to_category(df):
    bins = [18, 25, 35, 60, 100]
    group_names= ['Youth', 'Young-Adult', 'Middle-Aged', 'Senior']
    df['category'] = pd.cut(df['age'], bins, labels = group_names)
    return (df.head())

# %%
age_to_category(df_Cust)
# Out:
#              gender  past_3_years_bike_related_purchases  \
# customer_id
# 1            Female                                   93
# 2              Male                                   81
# 3              Male                                   61
# 4              Male                                   33
# 5            Female                                   56
#
#                           job_title job_industry_category     wealth_segment  \
# customer_id
# 1               Executive Secretary                Health      Mass Customer
# 2            Administrative Officer    Financial Services      Mass Customer
# 3                Recruiting Manager              Property      Mass Customer
# 4                               NaN                    IT      Mass Customer
# 5                     Senior Editor                   NaN  Affluent Customer
#
#             owns_car  tenure   age     category
# customer_id
# 1                Yes    11.0  67.0       Senior
# 2                Yes    16.0  40.0  Middle-Aged
# 3                Yes    15.0  66.0       Senior
# 4                 No     7.0  59.0  Middle-Aged
# 5                Yes     8.0  43.0  Middle-Aged

# %%
df1_df2= pd.merge(df_Cust, df_trans, how= 'inner', on = 'customer_id')

# %%
df1_df2
# Out:
#        customer_id  gender  past_3_years_bike_related_purchases  \
# 0                1  Female                                   93
# 1                1  Female                                   93
# 2                1  Female                                   93
# 3                1  Female                                   93
# 4                1  Female                                   93
# ...            ...     ...                                  ...
# 19437         3500  Female                                   71
# 19438         3500  Female                                   71
# 19439         3500  Female                                   71
# 19440         3500  Female                                   71
# 19441         3500  Female                                   71
#
#                  job_title job_industry_category     wealth_segment owns_car  \
# 0      Executive Secretary                Health      Mass Customer      Yes
# 1      Executive Secretary                Health      Mass Customer      Yes
# 2      Executive Secretary                Health      Mass Customer      Yes
# 3      Executive Secretary                Health      Mass Customer      Yes
# 4      Executive Secretary                Health      Mass Customer      Yes
# ...                    ...                   ...                ...      ...
# 19437                  NaN         Entertainment  Affluent Customer       No
# 19438                  NaN         Entertainment  Affluent Customer       No
# 19439                  NaN         Entertainment  Affluent Customer       No
# 19440                  NaN         Entertainment  Affluent Customer       No
# 19441                  NaN         Entertainment  Affluent Customer       No
#
#        tenure   age     category  ...  order_status           brand  \
# 0        11.0  67.0       Senior  ...      Approved      OHM Cycles
# 1        11.0  67.0       Senior  ...      Approved           Solex
# 2        11.0  67.0       Senior  ...      Approved   Trek Bicycles
# 3        11.0  67.0       Senior  ...      Approved  Norco Bicycles
# 4        11.0  67.0       Senior  ...      Approved           Solex
# ...       ...   ...          ...  ...           ...             ...
# 19437    17.0  53.0  Middle-Aged  ...      Approved  Giant Bicycles
# 19438    17.0  53.0  Middle-Aged  ...      Approved        WeareA2B
# 19439    17.0  53.0  Middle-Aged  ...      Approved  Giant Bicycles
# 19440    17.0  53.0  Middle-Aged  ...      Approved        WeareA2B
# 19441    17.0  53.0  Middle-Aged  ...      Approved      OHM Cycles
#
#        product_line product_class product_size list_price standard_cost  \
# 0          Standard        medium       medium     235.63        125.07
# 1          Standard        medium       medium    1577.53        826.51
# 2              Road           low        small    1720.70       1531.42
# 3          Standard        medium       medium     360.40        270.30
# 4          Standard        medium       medium      71.49         53.62
# ...             ...           ...          ...        ...           ...
# 19437          Road        medium       medium     792.90        594.68
# 19438      Standard        medium       medium    1228.07        400.91
# 19439      Standard        medium        small    1311.44       1167.18
# 19440      Standard        medium       medium      60.34         45.26
# 19441      Standard          high       medium    1458.17        874.90
#
#       product_first_sold_date  profit  Month
# 0                     38482.0   111.0     12
# 1                     39526.0   751.0      4
# 2                     37823.0   189.0      5
# 3                     37873.0    90.0      1
# 4                     38573.0    18.0      2
# ...                       ...     ...    ...
# 19437                 33879.0   198.0      1
# 19438                 36668.0   827.0      2
# 19439                 33888.0   144.0      8
# 19440                 34165.0    15.0      1
# 19441                 38750.0   583.0      3
#
# [19442 rows x 23 columns]

# %%
Age_group= df1_df2[['category', 'list_price']]
Age_group.head()
# Out:
#   category  list_price
# 0   Senior      235.63
# 1   Senior     1577.53
# 2   Senior     1720.70
# 3   Senior      360.40
# 4   Senior       71.49

# %%
grouped = Age_group.groupby("category").sum()
grouped
# Out:
#               list_price
# category
# Youth         2552081.87
# Young-Adult   3843019.29
# Middle-Aged  12304015.84
# Senior        2279070.04

# %%
x2= grouped.index
y2= grouped.list_price

plt.title("By Age Group")

colors = np.array(['lightpink', 'lightpink', 'deeppink','lightpink'])

#plt.xlabel(labels, fontweight='bold', color = 'orange', fontsize='9', horizontalalignment='center')

plt.bar(x2, y2, color= colors)
plt.show()

# %% [markdown]
# ####  2. Which gender bought spent more?

# %%
Gender= df1_df2[['gender', 'list_price']]
Gender.head()
# Out:
#    gender  list_price
# 0  Female      235.63
# 1  Female     1577.53
# 2  Female     1720.70
# 3  Female      360.40
# 4  Female       71.49

# %%
grouped1= Gender.groupby('gender').sum()
grouped1.head()
# Out:
#             list_price
# gender
# Female     10724659.62
# Male       10289573.08
# Undefined    516419.10

# %%
x3= grouped1.index
y3= grouped1.list_price

plt.title("By Gender")

colors = np.array(['lightpink', 'lightpink', 'deeppink'])

#plt.xlabel(labels, fontweight='bold', color = 'orange', fontsize='9', horizontalalignment='center')

plt.bar(x3, y3, color= colors)
plt.show()
